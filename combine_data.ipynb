# %%
# !pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/3d/44/c4218d351df907c9a39add2d93594ede085a6dc53b5760c67f1eca7871bf/matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/51/03/36ecc6fd1d018336625ad91b91fd34cd9ba8da5d36f5e1167dfe3275070a/contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/dd/bd/cb8fd2dddd68089c112bf42a88afe188b8ace73f94406539857dcc9347a6/fonttools-4.53.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 586.1 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import matplotlib

# %%
prosperity = pd.read_csv('data/2023_world_prosperity.csv')
prosperity.head()
# Out:
#          Country  AveragScore  SafetySecurity  PersonelFreedom  Governance  \
# 0        Denmark        84.55           92.59            94.09       89.45
# 1         Sweden        83.67           90.97            91.90       86.41
# 2         Norway        83.59           93.30            94.10       89.66
# 3        Finland        83.47           89.56            91.96       90.41
# 4    Switzerland        83.42           95.66            87.50       87.67
#
#    SocialCapital  InvestmentEnvironment  EnterpriseConditions  \
# 0          82.56                  82.42                 79.64
# 1          78.29                  82.81                 75.54
# 2          79.03                  82.24                 75.95
# 3          77.27                  84.12                 77.25
# 4          69.14                  80.81                 83.84
#
#    MarketAccessInfrastructure  EconomicQuality  LivingConditions  Health  \
# ...

# %%
happiness = pd.read_csv('data/WHR2023.csv')
happiness.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
cost_of_living = pd.read_csv('data/wikipedia_cost_of_living_indices3.csv')
cost_of_living.head()
# Out:
#        Country  Cost of Living Index  Rent Index  \
# 0  Switzerland                 101.1        46.5
# 1      Bahamas                  85.0        36.7
# 2      Iceland                  83.0        39.2
# 3    Singapore                  76.7        67.2
# 4     Barbados                  76.6        19.0
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            74.9            109.1                    97.0
# 1                            61.8             81.6                    83.3
# 2                            62.0             88.4                    86.8
# 3                            72.1             74.6                    50.4
# 4                            48.9             80.8                    69.4
#
#    Local Purchasing Power Index
# 0                         158.7
# 1                          54.6
# 2                         120.3
# 3                         111.1
# 4                          43.5

# %%
info = pd.read_csv('data/world-data-2023.csv')
info.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
info.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
health_cols = ['Country', 'Density\n(P/Km2)', 'Abbreviation', 
               'Agricultural Land( %)', 'Birth Rate', 'Co2-Emissions', 'CPI', 
               'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)', 
               'Gasoline Price', 'GDP','Gross primary education enrollment (%)',
               'Gross tertiary education enrollment (%)', 'Infant mortality',
               'Life expectancy', 'Maternal mortality ratio', 'Minimum wage', 
               'Out of pocket health expenditure', 'Physicians per thousand', 
               'Population', 'Population: Labor force participation (%)', 
               'Tax revenue (%)', 'Total tax rate', 'Unemployment rate', 
               'Urban_population', 'Latitude', 'Longitude']

# %%
health_info = info[health_cols].rename(columns={'Country':'Country Name'}).set_index('Country Name')

# %%
hospital_df = pd.read_csv('data/Hospital_Ranking_Data_2023.csv')
hospital_df
# Out:
#                                        Hospital Name   Country Name  \
# 0                                   Cleveland Clinic  United States
# 1               St Jude Children's Research Hospital  United States
# 2                             Johns Hopkins Medicine  United States
# 3                          Mayo Clinic Scottsdale AZ  United States
# 4              University of Maryland Medical Center  United States
# ...                                              ...            ...
# 11997                       Polyclinique Santa Maria         France
# 11998                              Sanatorio Mautone        Uruguay
# 11999  Zentrum für Orthopadische Chirurgie Pfaffikon    Switzerland
# 12000              Marienkrankenhaus Wickede Wimbern        Germany
# 12001                       Volga City Hospital nr 1         Russia
#
#       Global Ranking Hospital Size Visibility  Rich Files  Scholarship Score
# ...

# %%
hospital_df=hospital_df.loc[hospital_df['Global Ranking']!='N']
hospital_df
# Out:
#                                        Hospital Name   Country Name  \
# 0                                   Cleveland Clinic  United States
# 1               St Jude Children's Research Hospital  United States
# 2                             Johns Hopkins Medicine  United States
# 3                          Mayo Clinic Scottsdale AZ  United States
# 4              University of Maryland Medical Center  United States
# ...                                              ...            ...
# 11997                       Polyclinique Santa Maria         France
# 11998                              Sanatorio Mautone        Uruguay
# 11999  Zentrum für Orthopadische Chirurgie Pfaffikon    Switzerland
# 12000              Marienkrankenhaus Wickede Wimbern        Germany
# 12001                       Volga City Hospital nr 1         Russia
#
#       Global Ranking Hospital Size Visibility  Rich Files  Scholarship Score
# ...

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12000 entries, 0 to 12001
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Hospital Name      12000 non-null  object
#  1   Country Name       12000 non-null  object
#  2   Global Ranking     12000 non-null  int64
#  3   Hospital Size      12000 non-null  object
#  4   Visibility         12000 non-null  object
#  5   Rich Files         12000 non-null  float64
#  6   Scholarship Score  12000 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 750.0+ KB

# %%
hospital_df['Global Ranking'] = pd.to_numeric(hospital_df['Global Ranking'])
hospital_df['Hospital Size'] = pd.to_numeric(hospital_df['Hospital Size'])
# Out:
# /var/folders/f6/kpn2y4h53t569g316xl_gz580000gn/T/ipykernel_47687/407039949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df['Global Ranking'] = pd.to_numeric(hospital_df['Global Ranking'])
# /var/folders/f6/kpn2y4h53t569g316xl_gz580000gn/T/ipykernel_47687/407039949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df['Hospital Size'] = pd.to_numeric(hospital_df['Hospital Size'])

# %%
grouped_hosp = pd.concat([hospital_df.groupby('Country Name')['Country Name'].count(),hospital_df.groupby('Country Name')[['Global Ranking','Hospital Size']].agg(['min','max'])],axis='columns')
# grouped_hosp.columns = ['Number of Ranked Hospitals', 'Average Ranking', 'Best Ranking', 'Lowest Ranking', 'Average Hospital Size','Smallest Hospital', 'Largest Hospital']
grouped_hosp.columns = ['Number of Ranked Hospitals','Best Ranking', 'Lowest Ranking', 'Smallest Hospital', 'Largest Hospital']
grouped_hosp = grouped_hosp.sort_values(['Best Ranking']) 

grouped_hosp.head(50)
# Out:
#                 Number of Ranked Hospitals  Best Ranking  Lowest Ranking  \
# Country Name
# United States                         3619             1           11993
# France                                 380             8           11993
# Taiwan                                 138            13           11691
# Brazil                                 214            21           11949
# Germany                                822            22           11999
# Netherlands                            112            23           11940
# China                                  705            25           11964
# Canada                                 306            26           11869
# Switzerland                            238            35           11999
# Hong Kong                               21            39           11972
# Sweden                                  23            41           11117
# Japan                                  918            43           11981
# ...

# %%
# grouped_hosp.plot(kind='bar',figsize=(15,15))
grouped_hosp[['Number of Ranked Hospitals','Best Ranking','Largest Hospital']].plot(figsize=(15,15))
# Out:
# <Axes: xlabel='Country Name'>

# %%
# hospital_df.groupby('Country Name')['Country Name'].count()
# hospital_df[].value_counts()
df = pd.merge(grouped_hosp,health_info[['Population','Life expectancy','Physicians per thousand', 'Infant mortality','Maternal mortality ratio']],left_index=True,right_index=True).dropna()
df
# Out:
#                Number of Ranked Hospitals  Best Ranking  Lowest Ranking  \
# Country Name
# United States                        3619             1           11993
# France                                380             8           11993
# Brazil                                214            21           11949
# Germany                               822            22           11999
# Netherlands                           112            23           11940
# ...                                   ...           ...             ...
# Sudan                                   1         10759           10759
# Montenegro                              1         10888           10888
# Cambodia                                1         11091           11091
# Saint Lucia                             1         11445           11445
# El Salvador                             1         11835           11835
#
#                Smallest Hospital  Largest Hospital   Population  \
# Country Name
# ...

# %%
df['Population']=pd.to_numeric(df['Population'].str.replace(',',''))

# %%
df['Estimated Number of Physicians']=df['Population']/1000 * df['Physicians per thousand']

# %%
# df.drop(columns='Population').plot()
df['Normalized Population'] =df['Population']/(df['Population'].mean())
df['Normalized Life Expectancy'] =(df['Life expectancy']/df['Life expectancy'].mean())*10
df['Normalized Infant Mortality'] =df['Infant mortality']/df['Infant mortality'].mean()
df['Normalized Maternal Mortality'] =df['Maternal mortality ratio']/df['Maternal mortality ratio'].mean()
df['Normalized Ranked Hospital Count'] =df['Number of Ranked Hospitals']/df['Number of Ranked Hospitals'].mean()
df['Ranked Hospitals per Million'] = df['Number of Ranked Hospitals']/(df['Population']/1000000)
df['Normalized Hospitals per Population'] = (df['Number of Ranked Hospitals']/df['Population'])/(df['Number of Ranked Hospitals']/df['Population']).mean()

# %%
# df[['Ranked Hospitals per Million','Normalized Population','Life expectancy','Physicians per thousand']].plot(figsize = (15,10))

# %%
df=df.sort_values(['Normalized Infant Mortality','Normalized Maternal Mortality'])
df
# Out:
#                                   Number of Ranked Hospitals  Best Ranking  \
# Country Name
# Finland                                                   21           225
# Iceland                                                    6           663
# Slovenia                                                  10           294
# Japan                                                    918            43
# Luxembourg                                                 9          1966
# ...                                                      ...           ...
# Haiti                                                      1          3352
# Pakistan                                                  20          1842
# Democratic Republic of the Congo                           1         10137
# Nigeria                                                    5          2091
# Somalia                                                    1          4149
#
# ...

# %%
df[['Physicians per thousand','Normalized Infant Mortality','Normalized Maternal Mortality','Normalized Life Expectancy']].plot(kind='line',figsize=(20,10))
# Out:
# <Axes: xlabel='Country Name'>

# %%
df[['Normalized Hospitals per Population','Normalized Infant Mortality','Normalized Maternal Mortality','Normalized Life Expectancy',]].plot(kind='line',figsize=(20,10))
# Out:
# <Axes: xlabel='Country Name'>
